# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow import keras

# %%
### only run once! sets up working directory to be /quality_issue_predictor
import os
os.chdir(os.getcwd()[:-34] + r'\quality_issue_predictor')

# %% [markdown]
# ### Purpose:
# Generate a model using only the archived shop order data set.
# Why:
#     Because currently the shop order data does not intersect with the plantstar data yet.  Using only shop order potentially increases the training size 5-fold from previous model.

# %%
archived_df = pd.read_csv('./clean_data/archived_so.csv')
archived_df = archived_df.drop(columns = 'Unnamed: 0')
ncs_df = pd.read_csv('./clean_data/NCs.csv')

# %%
archived_df.head()
# Out:
#    Shop Order   Component    MRdate      MQISS     Product  BOM qty  MOPNO  \
# 0      186151       RM129  20190422  57534.048       V8536   20.592     20
# 1      186151       RM093  20190422      0.000       V8536    0.000     20
# 2      186151       RM160  20190422      0.000       V8536    0.000     20
# 3      182831  FS10017466  20190901      0.000  8881907102    0.000      0
# 4      182831     EXP6021  20190901      0.000  8881907102    0.000      0
#
#    Finished qty     MQREQ  Requested qty Lot Number        Date
# 0        2794.0  57451.68         2790.0   18M09063  2019-04-22
# 1        2794.0      0.00         2790.0   18M09063  2019-04-22
# 2        2794.0      0.00         2790.0   18M09063  2019-04-22
# 3         120.0      0.00          120.0  18C16263X  2019-09-01
# 4         120.0      0.00          120.0  18C16263X  2019-09-01

# %%
print(archived_df.shape)
# Out:
# (73239, 12)

# %% [markdown]
# ### One-Hot encoding everything

# %%
#remove formula sheets (probably no value)
archived_df = archived_df[(archived_df['Component'].str.contains('FS')==False) & (archived_df['Component'].str.contains('DC')==False)]\
                .reset_index(drop=True)
archived_df.shape
# Out:
# (63698, 12)

# %%
archived_df.head()
# Out:
#    Shop Order   Component    MRdate      MQISS     Product  BOM qty  MOPNO  \
# 0      186151       RM129  20190422  57534.048       V8536   20.592     20
# 1      186151       RM093  20190422      0.000       V8536    0.000     20
# 2      186151       RM160  20190422      0.000       V8536    0.000     20
# 3      182831     EXP6021  20190901      0.000  8881907102    0.000      0
# 4      182831  PT00004155  20190901      0.000  8881907102    0.000      0
#
#    Finished qty     MQREQ  Requested qty Lot Number        Date
# 0        2794.0  57451.68         2790.0   18M09063  2019-04-22
# 1        2794.0      0.00         2790.0   18M09063  2019-04-22
# 2        2794.0      0.00         2790.0   18M09063  2019-04-22
# 3         120.0      0.00          120.0  18C16263X  2019-09-01
# 4         120.0      0.00          120.0  18C16263X  2019-09-01

# %%
all_components = set(archived_df.Component)

# %%
resins = set()
for component, frame in archived_df.groupby(by = 'Component'):
    if component[0:2] == 'RM':
        resins.add(component)
print(resins)
print(len(resins))
# Out:
# {'RM169', 'RM260', 'RM112', 'RM093', 'RM031', 'RM168', 'RM201', 'RM129', 'RM106', 'RM032', 'RM154', 'RM026', 'RM070', 'RM165', 'RM074', 'RM170', 'RM220', 'RM160', 'RM157', 'RM004', 'RM020', 'RM025', 'RM054', 'RM171', 'RM176'}
# 25

# %%
PTcomponents = set()
for component, frame in archived_df.groupby(by = 'Component'):
    if component[0:2] == 'PT':
        PTcomponents.add(component)
print(PTcomponents)
print(len(PTcomponents))
# Out:
# {'PT00013699', 'PT00104295', 'PT00013694', 'PT00009994', 'PT00096237', 'PT00033969', 'PT00046937', 'PT00069525', 'PT00034294', 'PT00047930', 'PT00015631', 'PT00012138', 'PT00005149', 'PT00067913', 'PT00006635', 'PT00006657', 'PT00068805', 'PT00068683', 'PT00075579', 'PT00033501', 'PT00006682', 'PT00065936', 'PT00006610', 'PT00034306', 'PT00033972', 'PT00013702', 'PT00096202', 'PT00006651', 'PT00005525', 'PT00012247', 'PT00044728', 'PT00016495', 'PT00062563', 'PT00044733', 'PT00006653', 'PT00067914', 'PT00075580', 'PT00055730', 'PT00006673', 'PT00089213', 'PT00013696', 'PT00012137', 'PT00013703', 'PT00006655', 'PT00015840', 'PT00055216', 'PT00033502', 'PT00034377', 'PT00067916', 'PT00006672', 'PT00049846', 'PT00013707', 'PT00067917', 'PT00068803', 'PT00015857', 'PT00034305', 'PT00006659', 'PT00067915', 'PT00006650', 'PT00013692', 'PT00006688', 'PT00012250', 'PT00062605', 'PT00004155', 'PT00006646', 'PT00068808', 'PT00052701', 'PT00065943', 'PT00049845', 'PT00006674', 'PT00006677', 'PT00055729', 'PT00096177', 'PT00016490', 'PT00033970', 'PT00012252', 'PT00033971', 'PT00065939', 'PT00068806', 'PT00052518', 'PT00012105', 'PT00046145', 'PT00006652', 'PT00006671', 'PT00048792', 'PT00067912', 'PT00065942', 'PT00044732', 'PT00047934', 'PT00005527', 'PT00034301', 'PT00005153', 'PT00006643', 'PT00016498', 'PT00103021'}
# 95

# %%
FScomponents = set()
for component, frame in archived_df.groupby(by = 'Component'):
    if component[0:2] == 'FS':
        FScomponents.add(component)
print(FScomponents)
print(len(FScomponents))
# Out:
# set()
# 0

# %%
CLcomponents = set()
for component, frame in archived_df.groupby(by = 'Component'):
    if component[0:2] == 'CL':
        CLcomponents.add(component)
print(CLcomponents)
print(len(CLcomponents))
# Out:
# {'CL63R1771', 'CL63R98338', 'CL63R9962A', 'CL63R9828', 'CL63RR98416', 'CL63R4445', 'CL63R1784', 'CL63R98355', 'CL63R98461A', 'CL63R98334A', 'CL63R1040', 'CL63R1706', 'CL63R9881A', 'CL63R98346', 'CL63R1774', 'CL63R1653', 'CL63R98211', 'CL63R1781', 'CL63R98474A', 'CL63R1770A', 'CL63R9876B', 'CL63R98396A', 'CL63R1767A', 'CL63R1146', 'CL63R1777', 'CL63R98234', 'CL63R1769B', 'CL63R98173', 'CL63R98226', 'CL63R1654', 'CL63R9869A', 'CL63R1779', 'CL63R1783', 'CL63R1778', 'CL63R1780', 'CL63R98337A', 'CL63R1768B', 'CL63R1782', 'CL63R3908', 'CL63R9870B', 'CL63R1796', 'CL63R98407A', 'CL63R98482', 'CL63R1603', 'CL63R9960A', 'CL63R1794', 'CL63R1773', 'CL63R4153', 'CL63R1776'}
# 49

# %%
Rcomponents = set()
for component, frame in archived_df.groupby(by = 'Component'):
    if (component[0] == 'R') & (component[1]!='M'):
        Rcomponents.add(component)
print(Rcomponents)
print(len(Rcomponents))
# Out:
# {'R1635A', 'R1333D', 'R1690', 'R1594', 'R9242D', 'R1694', 'R98189', 'R7027MW', 'R7089W-1', 'R1025D', 'R1528A', 'R1567', 'R5098', 'R1695', 'R1681', 'R1292D', 'R1324D', 'R1705', 'R4237', 'R1471B', 'R1565B', 'R8534', 'R3712', 'R1697', 'R98184', 'R7028NMW', 'R1293D', 'R1748', 'R1378B', 'R1073D', 'R1317D', 'R4395', 'R9366D', 'R98350', 'R1158', 'R5097', 'R7421BL', 'R7408', 'R7626', 'R1680', 'R1149', 'R7611', 'R1704', 'R7545', 'R1679', 'R98399A', 'R1698', 'R1626A', 'R1300D', 'R1481B', 'R1057', 'R7046MW', 'R4226A', 'R1741', 'R1644A', 'R9801', 'R98190', 'R1474', 'R1075', 'R1302D', 'R4415', 'R1308D', 'R1749', 'R8550LGB', 'R1156C', 'R98028', 'R98034', 'R9806', 'R1306D', 'R8535', 'R7417', 'R1246D', 'R7637', 'R8554B', 'R1693', 'R98027', 'R1800', 'R7616', 'R98179', 'R1160D', 'R8930LA', 'R7472', 'R1700', 'R2000', 'R1338D', 'R1320D', 'R98405B', 'R7642B', 'R7028MW', 'R1035', 'R5104', 'R1750', 'R7013', 'R8516-1HB', 'R8550', 'R98180', 'R9249D'}
# 97

# %%
WPcomponents = set()
for component, frame in archived_df.groupby(by = 'Component'):
    if component[0:2] == 'WP':
        WPcomponents.add(component)
print(WPcomponents)
print(len(WPcomponents))
# Out:
# {'WP8965MW', 'WP7024K', 'WP3204', 'WP7026', 'WP7450BLNB', 'WP8540', 'WP8998P', 'WP8520N', 'WP7417', 'WP8836P', 'WP8920', 'WP8982', 'WP8860', 'WP7409', 'WP8998', 'WP8979', 'WP8520U', 'WP7483', 'WP7026P', 'WP7450', 'WP7418', 'WP8965N', 'WP4810', 'WP0001PKG', 'WP7417BLNB', 'WP851201N', 'WP7102', 'WP7449', 'WP8512U', 'WP7450BL', 'WP8836PNB', 'WP8825', 'WP7029N', 'WP8510', 'WP8986', 'WP7417BL', 'WP0003PKG', 'WP3206', 'WP8520N02', 'WP8526', 'WP7445', 'WP8935', 'WP7417P', 'WP7478', 'WP8985', 'WP7477', 'WP8850', 'WP8965U', 'WP8980-C', 'WP7605', 'WP8964', 'WP0002PKG', 'WP8999'}
# 53

# %%
all_components.difference(FScomponents.union(PTcomponents,resins,CLcomponents,Rcomponents,WPcomponents))
# Out:
# {'0301001',
#  '0301009',
#  '0400145',
#  '0420650',
#  '3154021',
#  '3201413',
#  '4001204',
#  '4001801',
#  '4006202',
#  '4101801',
#  '4220125',
#  '4230505',
#  '4500906',
#  '4502575',
#  '5000109',
#  '5000231',
#  '5030483',
#  '5151171',
#  '5170114',
#  '5170406',
#  '5170588',
#  '5170969',
#  '5241005',
#  '5241006',
#  '5241008',
#  '5241008R',
#  '5500148',
#  '5500149',
#  '5510301',
#  '5510320',
#  '5510509',
#  '5542735',
#  '7777129656',
#  '8507SA',
#  'CM285160000',
#  'CM285160071',
#  'EXP1020',
#  'EXP5001',
#  'EXP5013',
#  'EXP5050',
#  'EXP6001',
#  'EXP6020',
#  'EXP6021',
#  'EXP6026',
#  'EXP6027',
#  'EXP6029',
#  'X98140',
#  'X98141',
#  'X98142',
#  'X98146',
#  'X98151',
#  'X9894',
#  'X9898',
#  'X9899',
#  'X9901'}

# %%
archived_df[archived_df['Component'] == '8507SA']
# Out:
#        Shop Order Component    MRdate   MQISS Product  BOM qty  MOPNO  \
# 2924       188686    8507SA  20190619   69.00   8556H     0.05     20
# 3668       189187    8507SA  20190910   68.40   8556H     0.05     20
# 9868       193921    8507SA  20201013    0.00   8556H     0.05     20
# 19358      188515    8507SA  20190717   69.00   8556H     0.05     20
# 20861      189966    8507SA  20191015   69.00   8556H     0.05     20
# 25521      191573    8507SA  20200602   96.60   8556H     0.05     20
# 32785      187131    8507SA  20190313    0.00   8556H     0.05     20
# 34286      187945    8507SA  20190524    6.40   8556H     0.05     20
# 38957      190827    8507SA  20200206   72.00   8556H     0.05     20
# 43491      193774    8507SA  20200915  100.05   8556H     0.05     20
# 45502      194349    8507SA  20201202  103.50   8556H     0.05     20
# 47762      194486    8507SA  20210309   75.90   8556H     0.05     20
# 48475      196729    8507SA  20210602    0.00   8556H     0.05     20
# 52201      187440    8507SA  20190507   60.70   8556H     0.05     20
# 55981      190550    8507SA  20191209   75.90   8556H     0.05     20
# 58430      193132    8507SA  20200805   75.90   8556H     0.05     20
# 59893      194381    8507SA  20210106   46.00   8556H     0.05     20
#
#        Finished qty   MQREQ  Requested qty Lot Number        Date
# 2924         1380.0   69.00         1380.0   19E16463  2019-06-19
# 3668         1360.0   68.40         1368.0   19G02063  2019-09-10
# 9868         1151.0   57.10         1142.0   20H13263  2020-10-13
# 19358        1449.0   69.00         1380.0   19E08563  2019-07-17
# 20861        1439.0   69.00         1380.0   19H24463  2019-10-15
# 25521        1932.0   96.60         1932.0   20A20463  2020-06-02
# 32785        1256.0   58.65         1173.0   19B22363  2019-03-13
# 34286         128.0    6.40          128.0   19C25863  2019-05-24
# 38957        1412.0   70.60         1412.0   19L10163  2020-02-06
# 43491        2001.0  100.05         2001.0   20H01963  2020-09-15
# 45502        2020.0  103.50         2070.0   20J17063  2020-12-02
# 47762        2312.0  110.40         2208.0   20K03863  2021-03-09
# 48475        1311.0   65.55         1311.0   21C31263  2021-06-02
# 52201        1214.0   60.70         1214.0   19B44563  2019-05-07
# 55981        1560.0   75.90         1518.0   19K14463  2019-12-09
# 58430        1518.0   75.90         1518.0   20F00363  2020-08-05
# 59893         920.0   46.00          920.0   20J19263  2021-01-06

# %%
parts = pd.read_csv(open('./reference_data/parts.csv',encoding = "ISO-8859-1"))
parts = parts[['Number','Description - Long','Lifecycle Phase']][parts['Lifecycle Phase'] == 'Active']\
        .reset_index(drop=True)

# %%
for i, description in enumerate(parts['Description - Long']):
    if 'Resin' in description:
        parts.loc[i,'component_type'] = 'Resin'
    if 'Colorant' in description:
        parts.loc[i,'component_type'] = 'Colorant'
    if ('Plunger' in description) or ('PLGR' in description):
        parts.loc[i,'component_type'] = 'Plunger'
    if 'Barrel' in description:
        parts.loc[i,'component_type'] = 'Barrel'
    if ('Videojet' in description) or ('INK'in description.upper()) or ('PAD PRINT' in description.upper()) :
        parts.loc[i,'component_type'] = 'Ink related'
    if ('PURGING' in description.upper()):
        parts.loc[i,'component_type'] = 'Ink related'
    if ('RUBBER TIP' in description.upper()):
        parts.loc[i,'component_type'] = 'Rubber Tip'
    if 'Lid, Scoop, and Door Assembly' in description:
        parts.loc[i,'component_type'] = 'Lid'
    if 'Gasketed Lid' in description:
        parts.loc[i,'component_type'] = 'Lid'
    if 'LID' in description.upper():
        parts.loc[i,'component_type'] = 'Lid'
    if 'Sleeve' in description:
        parts.loc[i,'component_type'] = 'Sleeve'
    if 'COWL & LID' in description:
        parts.loc[i,'component_type'] = 'Lid'
    if 'DOOR' in description.upper():
        parts.loc[i,'component_type'] = 'Lid'
    if ('CAP' in description.upper()) and ('SNAP' in description.upper()):
        parts.loc[i,'component_type'] = 'Lid'
    if ('CAP' in description.upper()) and ('CHEMO' in description.upper()):
        parts.loc[i,'component_type'] = 'Lid'

# %%
parts[parts['component_type'].isna()]
# Out:
#        Number                                 Description - Long  \
# 2      301006                                     POLYPRO 7824MR
# 20    3156002                       412 Syringe Assembly Phantom
# 37    4220104  Printing Foil for Hot Stamp Marking, 2.375 Inc...
# 38    4220125             Print Tape, Black, 3 Inch Wide, B215SL
# 41    4500005  Finished Component, MONOJECT 500E Hooded Needl...
# ..        ...                                                ...
# 612    WP7477  Chemotherapy Hood with Printed Instruction Lab...
# 613  WP7477NB  Pharmaceutical, Non Hazardous, Non Biohazard, ...
# 619    WP7596                     PRINTED TUMBLER FOR GATORGUARD
# 667     X9902                         Polybag, 13 Inch x 10 Inch
# 668   ZDZ1031                                BENT SIDE RAIL WIRE
#
#     Lifecycle Phase component_type
# 2            Active            NaN
# 20           Active            NaN
# 37           Active            NaN
# 38           Active            NaN
# 41           Active            NaN
# ..              ...            ...
# 612          Active            NaN
# 613          Active            NaN
# 619          Active            NaN
# 667          Active            NaN
# 668          Active            NaN
#
# [402 rows x 4 columns]

# %%
def test_word(word):
    for i, description in enumerate(parts['Description - Long']):
        if word in description:
            print(parts.iloc[i])
test_word('CAP')
# Out:
# Number                               EXP1020
# Description - Long    Ink, Black, CAPEX 7600
# Lifecycle Phase                       Active
# component_type                   Ink related
# Name: 136, dtype: object
# Number                                  PT00033969
# Description - Long    Ink, Black, CAPEX 9100 Dense
# Lifecycle Phase                             Active
# component_type                         Ink related
# Name: 210, dtype: object
# Number                                                 PT00096237
# Description - Long    2GAL FIP SNAP CAP  Sustainable Technologies
# Lifecycle Phase                                            Active
# component_type                                                lid
# Name: 265, dtype: object
# Number                     R7075BR
# Description - Long    RED SNAP CAP
# Lifecycle Phase             Active
# component_type                 lid
# Name: 399, dtype: object
# Number                        R7075BY
# Description - Long    YELLOW SNAP CAP
# Lifecycle Phase                Active
# component_type                    lid
# Name: 400, dtype: object
# Number                                       R7089BL
# Description - Long    2GAL BLUE HINGED LID, SNAP CAP
# Lifecycle Phase                               Active
# component_type                                   lid
# Name: 401, dtype: object
# Number                                        R7089W
# Description - Long    WHITE 2 GAL HINGED LID SNAPCAP
# Lifecycle Phase                               Active
# component_type                                   lid
# Name: 403, dtype: object
# Number                                      R7089W-1
# Description - Long    2 GAL. HINGED LID, WHT, NO CAP
# Lifecycle Phase                               Active
# component_type                                   Lid
# Name: 404, dtype: object
# Number                                   R7412
# Description - Long    SNAP CAP/PLUG FOR 5010SA
# Lifecycle Phase                         Active
# component_type                             lid
# Name: 410, dtype: object
# Number                                      R7449BL
# Description - Long    8GAL CHEMO SLIDE TOP CAP BLUE
# Lifecycle Phase                              Active
# component_type                                  lid
# Name: 428, dtype: object
# Number                                 R7451
# Description - Long    8/12/18 GAL. CHEMO CAP
# Lifecycle Phase                       Active
# component_type                           lid
# Name: 430, dtype: object
# Number                                        R7478
# Description - Long    PUNCT RESISTNT CHEMO CAP DISC
# Lifecycle Phase                              Active
# component_type                                  lid
# Name: 440, dtype: object
# Number                                      R9981
# Description - Long    #8-32 BLACK CAP NUT (X9979)
# Lifecycle Phase                            Active
# component_type                                NaN
# Name: 545, dtype: object
# Number                                      WP2200
# Description - Long    WHITE 2 GA LID W/RED SNAPCAP
# Lifecycle Phase                             Active
# component_type                                 lid
# Name: 589, dtype: object
# Number                                       WP2201
# Description - Long    WHITE 2 GA LID W/YELL SNAPCAP
# Lifecycle Phase                              Active
# component_type                                  lid
# Name: 590, dtype: object
# Number                                        WP2202
# Description - Long    BLUE 2 GA LID W/YELLOW SNAPCAP
# Lifecycle Phase                               Active
# component_type                                   lid
# Name: 591, dtype: object
# Number                                        WP3206
# Description - Long    LID & SNAP CAP ASSEM/NO GASKET
# Lifecycle Phase                               Active
# component_type                                   lid
# Name: 593, dtype: object
# Number                             WP7478
# Description - Long    CHEMO CAP DISC ASSM
# Lifecycle Phase                    Active
# component_type                        lid
# Name: 614, dtype: object
# Number                                        WP8825
# Description - Long    2GAL PharmaSafety FIP SNAP CAP
# Lifecycle Phase                               Active
# component_type                                   lid
# Name: 635, dtype: object

# %%
for comp in all_components:
    if (comp[0:2] == 'FS') or (comp[0:2]=='DC'):
        continue
    if len(parts[parts['Number'] == comp]) == 0:
        print(comp)
# Out:
# R7028NMW
# 8507SA
# R7408
# PT00006672
# R7046MW
# 0420650
# R7421BL
# CL63R9828
# CL63R98338
# 0400145
# WP7417
# 0301001
# R1333D
# RM201
# WP7409
# 7777129656
# R3712
# 4502575
# 0301009
# RM031
# R1338D
# R7028MW
